# %% [markdown]
# ## Gradient Descent: The Code

# %% [markdown]
# ### Two inputs, One output

# %%
import numpy as np

# Defining the sigmoid function for activations
def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1/(1+np.exp(-x))

# Derivative of the sigmoid function
def sigmoid_prime(x):
    """
    # Derivative of the sigmoid function
    """
    return sigmoid(x) * (1 - sigmoid(x))

# %%
# Input data
x = np.array([0.1, 0.3])

# Target
y = 0.2

# Input to output weights
weights = np.array([-0.8, 0.5])

# The learning rate, eta in the weight step equation
learnrate = 0.5

# %%
# the linear combination performed by the node (h in f(h) and f'(h))
h = np.dot(x, weights)
### or
"""
h = x[0]*weights[0] + x[1]*weights[1]
"""

# The neural network output (y-hat)
nn_output = sigmoid(h)

print('Neural Network output:')
print(nn_output)
# Out:
# Neural Network output:
# 0.5174928576663897

# %%
# output error (y - y-hat)
error = y - nn_output

print('Amount of Error:')
print(error)
# Out:
# Amount of Error:
# -0.31749285766638974

# %%
# output gradient (f'(h))
output_grad = sigmoid_prime(h)

# error term (lowercase delta)
error_term = error * output_grad

# Gradient descent step 
del_w = learnrate * error_term * x

### or 
"""
del_w = [ learnrate * error_term * x[0],
          learnrate * error_term * x[1]]
"""

print('Change in Weights:')
print(del_w)
# Out:
# Change in Weights:
# [-0.0039638  -0.01189141]

# %% [markdown]
# ### Four inputs, One output

# %%
import numpy as np

def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_prime(x):
    return sigmoid(x) * (1 - sigmoid(x))

# %%
# Input data
x = np.array([1, 2, 3, 4])

# Target
y = np.array(0.5)

# The learning rate, eta in the weight step equation
learnrate = 0.5

# Initial weights
w = np.array([0.5, -0.5, 0.3, 0.1])

# %%
### Calculate one gradient descent step for each weight
### Note: Some steps have been consolidated, so there are
###       fewer variable names than in the above sample code

# TODO: Calculate the node's linear combination of inputs and weights
h = np.dot(x, w)

# TODO: Calculate output of neural network
nn_output = sigmoid(h)

print('Neural Network output:')
print(nn_output)
# Out:
# Neural Network output:
# 0.6899744811276125

# %%
# TODO: Calculate error of neural network
error = y - nn_output

print('Amount of Error:')
print(error)
# Out:
# Amount of Error:
# -0.1899744811276125

# %%
# TODO: Calculate the error term
#       Remember, this requires the output gradient, which we haven't
#       specifically added a variable for.
error_term = error * sigmoid_prime(h)
# Note: The sigmoid_prime function calculates sigmoid(h) twice,
#       but you've already calculated it once. You can make this
#       code more efficient by calculating the derivative directly
#       rather than calling sigmoid_prime, like this:
# error_term = error * nn_output * (1 - nn_output)

# TODO: Calculate change in weights
del_w = learnrate * error_term * x

print('Change in Weights:')
print(del_w)
# Out:
# Change in Weights:
# [-0.02031869 -0.04063738 -0.06095608 -0.08127477]

# %% [markdown]
# ### Reference

# %%
from IPython.display import Image
Image("img/weight update.png")

# %% [raw]
# change in weights = learnrate * error_term * input_data
#                   = LR * error * output_gradient * input_data
#                   = LR * (y - y-hat) * f'(h) * x
#                   = LR * (target - neural_network_output) * sigmoid_prime(h) * x
#                   = LR * (y - sigmoid(h)) * sigmoid_prime(h) * x
#                   = LR * (y - sigmoid(np.dot(input_data, weights))) * sigmoid_prime(h) * x
#                   = LR * (y - sigmoid(np.dot(x, w))) * sigmoid_prime(h) * x
